# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
img=plt.imread("images.jpeg")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
img.size
# Out:
# 150975

# %%
wid,hig,d=img.shape
img_arr=img.reshape(wid*hig,d)
#normalizing image in the range of (0,1)
# img_arr=img_arr/255
img_arr.shape
# Out:
# (50325, 3)

# %%
img_arr
# Out:
# array([[192, 132,  10],
#        [178, 142,   6],
#        [164, 149,   0],
#        ...,
#        [ 82, 157,   2],
#        [ 82, 157,   2],
#        [ 82, 157,   2]], dtype=uint8)

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=64,random_state=1)
kmeans.fit(img_arr)
c=kmeans.cluster_centers_
# Out:
# /home/golu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#priting cluster centroids
c
# Out:
# array([[  7.29261863, 132.73066784, 218.29393673],
#        [208.36170213, 156.54158607,   5.30077369],
#        [112.65238678,  79.3121175 ,   6.52876377],
#        [243.14190687,   8.73392461,  15.3902439 ],
#        [143.34184397, 220.84539007,  79.68085106],
#        [  8.84517304,  93.20947177, 125.71584699],
#        [ 32.65107212,  78.80701754,   9.56725146],
#        [144.73913043, 231.17312253,   6.78814229],
#        [250.42574257, 238.50165017,  85.87458746],
#        [250.47203442, 202.52550707,   6.46773202],
#        [ 82.93183322, 152.13898081,   5.34943746],
#        [167.54492754,   6.08888889,   7.32850242],
#        [189.66550523, 249.54006969, 144.59581882],
#        [  6.35194805, 117.7978355 , 202.11125541],
#        [186.58375635, 139.0213198 ,   6.95634518],
#        [  6.36995828,  60.9123783 , 125.18358832],
#        [228.0952381 ,  17.4952381 , 146.47619048],
#        [127.93660532, 146.5807771 ,  26.80572597],
#        [ 66.98120301, 129.21052632,   5.61403509],
#        [ 95.18376068,  10.3482906 ,   9.41025641],
#        [192.99242424,  54.04924242,  60.04924242],
#        [  5.84045584,  97.58119658, 184.84188034],
#        [166.72397476, 239.38485804, 109.16719243],
#        [  8.79219144,  56.79093199,  88.76700252],
#        [ 67.39378238,  94.55440415, 133.25388601],
#        [ 54.95254833,  44.7029877 ,   9.87873462],
#        [ 56.57485876, 101.52118644,   7.93644068],
#        [251.74193548, 123.31451613, 189.02419355],
#        [235.36585366, 126.24390244,  11.56585366],
#        [219.46165528,   4.65299924,   6.95975702],
#        [110.15384615, 191.96191927,   5.58720487],
#        [ 56.37391304, 165.26521739, 238.40434783],
#        [ 19.80267559,  43.56521739,   9.13377926],
#        [138.22026432,  99.68575624,   7.02643172],
#        [  6.11005542,  83.4837688 , 158.49881235],
#        [103.07296137, 116.30901288,  59.28755365],
#        [253.13740023, 237.01710376,   6.54960091],
#        [243.875     ,  86.17045455, 103.82386364],
#        [162.95681063, 235.17275748,  34.21594684],
#        [223.80967742,  16.22741935,  35.30645161],
#        [  8.54982818, 114.10194731, 170.97938144],
#        [181.65384615, 170.21794872,  71.02564103],
#        [148.342723  ,  16.7370892 ,  90.98122066],
#        [ 95.56623586, 172.34975767,   8.75121163],
#        [185.42358079,  61.18340611,   8.01746725],
#        [ 10.84482759, 149.89034483, 232.83655172],
#        [124.06510067, 214.40134228,   5.22751678],
#        [226.01625239, 175.43977055,   5.99426386],
#        [115.60869565, 195.27639752,  54.5015528 ],
#        [ 62.23318386,  64.2735426 ,  63.97757848],
#        [136.52514793,   8.89053254,   8.64201183],
#        [163.63989962, 120.00752823,   6.93350063],
#        [ 39.65669014,  11.24647887,   8.04753521],
#        [ 11.27803379,  35.640553  ,  53.16282642],
#        [143.66071429, 195.05      ,  10.29464286],
#        [252.16888151, 220.8538206 ,   4.62236988],
#        [242.45758355,  42.36246787,  56.31105398],
#        [250.38448276, 230.03448276,  34.10517241],
#        [ 43.89090909, 151.82727273,  76.98181818],
#        [195.4398374 ,   5.75609756,   7.26747967],
#        [246.57724329, 182.26456984,   6.83903793],
#        [ 87.14749263,  60.67699115,   6.81415929],
#        [ 50.54770318, 132.5795053 , 191.92932862],
#        [  9.01417004,   9.51012146,   7.31477733]])

# %%
new_compressed_img3 =c[kmeans.labels_]
new_compressed_img3 = np.clip(new_compressed_img3.astype('uint8'), 0, 255)
new_compressed_img3 = new_compressed_img3.reshape(wid, hig, 3)

# %%
plt.figure(0)
plt.axis('off')
plt.title('original')
plt.imshow(img)
plt.show()
plt.figure(4)
plt.axis('off')
plt.title('Compressed @ k=64')
plt.imshow(new_compressed_img3)
plt.show()

# %%
kmeans=KMeans(n_clusters=5,random_state=1)
kmeans.fit(img_arr)
c=kmeans.cluster_centers_
# Out:
# /home/golu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
new_compressed_img1 =c[kmeans.labels_]
new_compressed_img1 = np.clip(new_compressed_img1.astype('uint8'), 0, 255)
new_compressed_img1 = new_compressed_img1.reshape(wid, hig, 3)
plt.figure(0)
plt.axis('off')
plt.title('original')
plt.imshow(img)
plt.show()
plt.figure(1)
plt.axis('off')
plt.title('Compressed @ k=5')
plt.imshow(new_compressed_img1)
plt.show()

# %%
kmeans=KMeans(n_clusters=20,random_state=1)
kmeans.fit(img_arr)
c=kmeans.cluster_centers_
# Out:
# /home/golu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
new_compressed_img2 =c[kmeans.labels_]
new_compressed_img2 = np.clip(new_compressed_img2.astype('uint8'), 0, 255)
new_compressed_img2 = new_compressed_img2.reshape(wid, hig, 3)
plt.figure(0)
plt.axis('off')
plt.title('original')
plt.imshow(img)
plt.show()
plt.figure(2)
plt.axis('off')
plt.title('Compressed @ k=20')
plt.imshow(new_compressed_img2)
plt.show()

# %%
kmeans=KMeans(n_clusters=128,random_state=1)
kmeans.fit(img_arr)
c=kmeans.cluster_centers_
# Out:
# /home/golu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
new_compressed_img4 =c[kmeans.labels_]
new_compressed_img4 = np.clip(new_compressed_img4.astype('uint8'), 0, 255)
new_compressed_img4 = new_compressed_img4.reshape(wid, hig, 3)
plt.figure(0)
plt.axis('off')
plt.title('original')
plt.imshow(img)
plt.show()
plt.figure(3)
plt.axis('off')
plt.title('Compressed @ k=128')
plt.imshow(new_compressed_img4)
plt.show()

# %%
#Comparing All
fig, axs = plt.subplots(2, 2,figsize=(10,10))
axs[0, 0].imshow(new_compressed_img1)
axs[0, 0].set_title('Reconstructed Image @ k=5', size=16)
axs[0, 1].imshow(new_compressed_img2)
axs[0, 1].set_title('Reconstructed Image @ k=20', size=16)
axs[1, 0].imshow(new_compressed_img3)
axs[1, 0].set_title('Reconstructed Image @ k=64', size=16)
axs[1, 1].imshow(new_compressed_img4)
axs[1, 1].set_title('Reconstructed Image @ k=128', size=16)
plt.tight_layout()
plt.show()
